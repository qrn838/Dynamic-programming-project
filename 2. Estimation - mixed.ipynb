# %%
import numpy as np
import matplotlib.pyplot as plt
from solve_consumption_saving import *
from copy import deepcopy
from estimation import *

# %load_ext autoreload
# %autoreload 2

# %pip install EconModel
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()
model.par.full_sample_estimation = True
model.allocate()
model_new = deepcopy(model)
model.par.model = 'Mixed'
model_new.par.model = 'Mixed'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # **Estimating using the full sample** #
# (using hazard rates from both before and after the reform)

# %% [markdown]
# # Model with reference dependence

# %%
# est_par = ['gamma', 'N', 'cost1', 'cost2', 'type_shares1', 'welfare'] # Parameters to estimate
# theta0 = [0.06, 15, 100.0, 300, 0.4, 90/675]  # Initial guesses
# bounds = [(0.01, 50.0), (0,50), (0.0,model.par.cost2), (model.par.cost1,1000.0), (0.0,1.0), (0.0,model.par.b3)] # Bounds for the parameters

# # S: Hvorfor estimerer den ikke N, men accepterer bare initial guess?
# # S: Bør vi løse problemet med initial guess ved at trække gættende fra en uniform fordeling som de gør i papiret?

# est = method_simulated_moments(model,est_par,theta0,bounds,weight=False)

# print("Optimization Results:")
# print("---------------------")
# print(f'{"Parameter":<15} {"Estimate":<15}')
# for param, estimate in zip(est_par, est.x):
#     print(f'{param:<15} {estimate:>15.3f}')
# print(f'Objective:               {est.fun:.4f}')
# print(f'Number of iterations:    {est.nit}')

# %%
model.par.eta = 1  # Reference dependence
model.par.types = 1  # No heterogeneity
model.par.euler = True
model.allocate()

est_par = ['delta', 'gamma', 'lambdaa', 'N', 'cost1', 'HTM_share'] # Parameters to estimate
theta0 = [0.95, 0.4, 2.0, 15, 100.0, 0.5]  # Initial guesses
bounds = [(0, 1), (0.0, 10.0), (0.0, 10.0), (0,50), (0.0,500), (0.0,1.0)] # Bounds for the parameters

est = method_simulated_moments(model, est_par,theta0,bounds,weight=False)

model.par.noOfParams = len(est_par)
model.par.noSearchInits = 1


# for i in range(model.par.noSearchInits):

#     theta0 = [np.random.uniform(0.7, 0.99),
#               np.random.uniform(model.par.lb_gam,model.par.ub_gam),
#               np.random.uniform(model.par.lb_sig,model.par.ub_sig),
#               np.random.uniform(model.par.lb_N,model.par.ub_N),
#               np.random.uniform(model.par.lb_lsc,500)]

#     est_best = np.inf
#     est = method_simulated_moments(model,est_par,theta0,bounds,weight=False)

#     if est.fun < est_best:
#         est_best = est.fun
#         par = est.x
#         nit = est.nit



print("Optimization Results:")
print("---------------------")
print(f'{"Parameter":<15} {"Estimate":<15}')
for param, estimate in zip(est_par, est.x):
    print(f'{param:<15} {estimate:>15.3f}')
print(f'Objective:               {est.fun:.4f}')
print(f'Number of iterations:    {est.nit}')
# Out:
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_mu = 1/c * (1+par.eta)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_mu = 1/c * (1+par.eta*par.lambdaa)
# c:\Users\marti\Anaconda\lib\site-packages\scipy\interpolate\_interpolate.py:698: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:64: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_c_marg[0] = (s/par.cost1)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:65: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_c_marg[1] = (s/par.cost2)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:66: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_c_marg[2] = (s/par.cost3)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:64: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[0] = (s/par.cost1)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:65: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[1] = (s/par.cost2)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:66: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[2] = (s/par.cost3)**(1/par.gamma)
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: 2.2358530460294896
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.2358530460294896
#        x: -0.8364059678206773
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: 0.9195011769289331
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9195011769289331
#        x: -0.8364083782252674
#      nit: 26
#     nfev: 26
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: 1.867120848717539
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.867120848717539
#        x: -0.7283457107293055
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: 1.6623999074151308
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.6623999074151308
#        x: -0.6398019567492544
#      nit: 25
#     nfev: 25
# Error at t=16, i_a=0
# Error message: NaN result encountered.
# Current function value: 4.0274300817856545
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.0274300817856545
#        x: -0.8770940609413934
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.71980124744843
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.71980124744843
#        x: -0.7746209981368495
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=1
# Error message: NaN result encountered.
# Current function value: 6.845601682360858
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.845601682360858
#        x: -0.8327799075873423
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.012601618027876
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.012601618027876
#        x: -0.7547779796982712
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=3
# Error message: NaN result encountered.
# Current function value: 3.6018313810798217
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.6018313810798217
#        x: -0.7547801410329142
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=4
# Error message: NaN result encountered.
# Current function value: 2.45918490134581
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.45918490134581
#        x: -0.7547802055931766
#      nit: 25
#     nfev: 25
# Error at t=10, i_a=0
# Error message: NaN result encountered.
# Current function value: 7.331087994924036
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.331087994924036
#        x: -0.8930018865645221
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=0
# Error message: NaN result encountered.
# Current function value: 10.00782888323809
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 10.00782888323809
#        x: -0.8475219523858176
#      nit: 22
#     nfev: 22
# Error at t=7, i_a=1
# Error message: NaN result encountered.
# Current function value: 8.576605159446252
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 8.576605159446252
#        x: -0.8210846109582318
#      nit: 23
#     nfev: 23
# Error at t=7, i_a=2
# Error message: NaN result encountered.
# Current function value: 6.676266424106171
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.676266424106171
#        x: -0.82108312627437
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=4
# Error message: NaN result encountered.
# Current function value: 4.069266621774322
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.069266621774322
#        x: -0.8210827023306038
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=6, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7277202998544219
#      nit: 24
#     nfev: 24
# Error at t=6, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6893279363500777
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=3
# Error message: NaN result encountered.
# Current function value: 2.503232335179247
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.503232335179247
#        x: -0.6179867782534091
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=5
# Error message: NaN result encountered.
# Current function value: 0.5438351268625442
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5438351268625442
#        x: -0.6179863762269624
#      nit: 27
#     nfev: 27
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=14, i_a=0
# Error message: NaN result encountered.
# Current function value: 6.63218790883523
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.63218790883523
#        x: -0.7972681991143644
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.178810544043178
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.178810544043178
#        x: -0.7896571269820187
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.3022289526960966
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.3022289526960966
#        x: -0.7896587570954965
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=2
# Error message: NaN result encountered.
# Current function value: 0.929966141700176
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.929966141700176
#        x: -0.7350936119317886
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=5
# Error message: NaN result encountered.
# Current function value: -0.28171151171753345
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.28171151171753345
#        x: -0.7350927232544046
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=6
# Error message: NaN result encountered.
# Current function value: -0.5637767423590384
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.5637767423590384
#        x: -0.7350931278215317
#      nit: 26
#     nfev: 26
# Error at t=12, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.8109325984685656
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.8109325984685656
#        x: -0.7350928941442155
#      nit: 26
#     nfev: 26
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.4400093787446773
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.4400093787446773
#        x: -0.7350923643595824
#      nit: 25
#     nfev: 25
# Error at t=11, i_a=6
# Error message: NaN result encountered.
# Current function value: -0.5637718370770097
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.5637718370770097
#        x: -0.7350912506483895
#      nit: 25
#     nfev: 25
# Error at t=11, i_a=8
# Error message: NaN result encountered.
# Current function value: -1.0308809385998232
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -1.0308809385998232
#        x: -0.7350943976926587
#      nit: 27
#     nfev: 27
# Error at t=11, i_a=9
# Error message: NaN result encountered.
# Current function value: -1.229013768054257
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -1.229013768054257
#        x: -0.7350929089447105
#      nit: 26
#     nfev: 26
# Error at t=10, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.6766418872217627
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.6766418872217627
#        x: -0.7441913263591962
#      nit: 25
#     nfev: 25
# Error at t=7, i_a=1
# Error message: NaN result encountered.
# Current function value: 8.71119402241414
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 8.71119402241414
#        x: -0.8043978963773354
#      nit: 24
#     nfev: 24
# Error at t=6, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=3
# Error message: NaN result encountered.
# Current function value: 5.808328811437823
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.808328811437823
#        x: -0.7215962156897592
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.621928009309118
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5835356458047738
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: 12.162954161744473
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 12.162954161744473
#        x: -0.7980332837696427
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=2
# Error message: NaN result encountered.
# Current function value: 6.230435109012488
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.230435109012488
#        x: -0.7980323390349506
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=2, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6987127363178063
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6603203728134621
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: 3.917580504871199
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.917580504871199
#        x: -0.6405549847922465
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=7
# Error message: NaN result encountered.
# Current function value: 2.622181382822104
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.622181382822104
#        x: -0.6405549847922465
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6987127363178063
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6603203728134621
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.621928009309118
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=5
# Error message: NaN result encountered.
# Current function value: 5.253175592500216
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.253175592500216
#        x: -0.6072641382758583
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=6
# Error message: NaN result encountered.
# Current function value: 3.6607288760520955
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.6607288760520955
#        x: -0.6072617030364367
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=9
# Error message: NaN result encountered.
# Current function value: 0.06911274945647136
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.06911274945647136
#        x: -0.607262690879778
#      nit: 20
#     nfev: 20
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7754974633264946
#      nit: 23
#     nfev: 23
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7371050998221504
#      nit: 23
#     nfev: 23
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6987127363178063
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6603203728134621
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.621928009309118
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5835356458047738
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=16, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.414920084835083
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.414920084835083
#        x: -0.8966482210905581
#      nit: 23
#     nfev: 23
# Error at t=15, i_a=2
# Error message: NaN result encountered.
# Current function value: 1.6572277611824382
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.6572277611824382
#        x: -0.8439519499431898
#      nit: 25
#     nfev: 25
# Error at t=15, i_a=3
# Error message: NaN result encountered.
# Current function value: 1.2038141364381287
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.2038141364381287
#        x: -0.8439517719625788
#      nit: 25
#     nfev: 25
# Error at t=15, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.8343830706360401
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.8343830706360401
#        x: -0.8439539242662422
#      nit: 26
#     nfev: 26
# Error at t=14, i_a=0
# Error message: NaN result encountered.
# Current function value: 6.864437395748253
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.864437395748253
#        x: -0.8642739513971865
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=0
# Error message: NaN result encountered.
# Current function value: 7.495521185339194
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.495521185339194
#        x: -0.837611611549941
#      nit: 22
#     nfev: 22
# Error at t=13, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.5222702649547006
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.5222702649547006
#        x: -0.8376097299524462
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=12, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=2
# Error message: NaN result encountered.
# Current function value: 3.0112700813928077
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.0112700813928077
#        x: -0.756233291150213
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.9258979024951384
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9258979024951384
#        x: -0.7562325776543398
#      nit: 24
#     nfev: 24
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=11, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.9642302541538837
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9642302541538837
#        x: -0.7310319420615528
#      nit: 25
#     nfev: 25
# Error at t=11, i_a=8
# Error message: NaN result encountered.
# Current function value: -0.7133682920307567
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.7133682920307567
#        x: -0.7310328701558466
#      nit: 26
#     nfev: 26
# Error at t=11, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.9284849666490749
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.9284849666490749
#        x: -0.7310345288332427
#      nit: 26
#     nfev: 26
# Error at t=10, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=3
# Error message: NaN result encountered.
# Current function value: 1.9690610760041185
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.9690610760041185
#        x: -0.7516317705937714
#      nit: 25
#     nfev: 25
# Error at t=10, i_a=4
# Error message: NaN result encountered.
# Current function value: 1.4482887932165243
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.4482887932165243
#        x: -0.7516299967570562
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=9, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8045050268631102
#      nit: 22
#     nfev: 22
# Error at t=8, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.766112663358766
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7277202998544219
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=3
# Error message: NaN result encountered.
# Current function value: 6.5931350742372015
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.5931350742372015
#        x: -0.726748225957854
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=0
# Error message: NaN result encountered.
# Current function value: 12.806696208573573
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 12.806696208573573
#        x: -0.8168312056386869
#      nit: 22
#     nfev: 22
# Error at t=7, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.483475058657596
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.483475058657596
#        x: -0.8168326604890866
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=3
# Error message: NaN result encountered.
# Current function value: 3.2461748329293996
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.2461748329293996
#        x: -0.8168318332218462
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=5
# Error message: NaN result encountered.
# Current function value: 0.34983590460192787
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.34983590460192787
#        x: -0.8168320497183176
#      nit: 26
#     nfev: 26
# Error at t=6, i_a=0
# Error message: NaN result encountered.
# Current function value: 15.485888590205915
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 15.485888590205915
#        x: -0.83714196388864
#      nit: 22
#     nfev: 22
# Error at t=6, i_a=1
# Error message: NaN result encountered.
# Current function value: 11.504427854707586
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 11.504427854707586
#        x: -0.8371421127767829
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: 6.036151165926832
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.036151165926832
#        x: -0.8022250190683965
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.991341288361628
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.991341288361628
#        x: -0.802224575714614
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.3172985080345008
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.3172985080345008
#        x: -0.8022261757320405
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.9000458625075298
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9000458625075298
#        x: -0.8022246694726776
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=5
# Error message: NaN result encountered.
# Current function value: 0.8366438304064296
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.8366438304064296
#        x: -0.6475888730004001
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=3
# Error message: NaN result encountered.
# Current function value: 4.039407720800341
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.039407720800341
#        x: -0.7514455186427801
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: 12.25483369165702
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 12.25483369165702
#        x: -0.8599175607779841
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: 10.440724113086166
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 10.440724113086166
#        x: -0.8599176628735908
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: 9.650830562492587
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 9.650830562492587
#        x: -0.7827124507367672
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: 7.514116681955356
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.514116681955356
#        x: -0.782711369697919
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.778874081990911
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.778874081990911
#        x: -0.7827141124423155
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: 3.0567286992808267
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.0567286992808267
#        x: -0.7827131728070853
#      nit: 25
#     nfev: 25
# Optimization Results:
# ---------------------
# Parameter       Estimate
# delta                     0.928
# gamma                     0.535
# lambdaa                   3.631
# N                        10.000
# cost1                   174.927
# HTM_share                 1.000
# Objective:               0.3155
# Number of iterations:    92

# %%
model.solve()
sim = model.sim.s_total
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, sim[:], color='navy', label='Before Reform') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.ylim(0.0, 0.08)
plt.legend()
plt.show()

# %%
model_after = deepcopy(model)
model_after.par.b1 = 342.0/675.0      # Value after reform
model_after.par.b2 = 171.0/675.0      # Value after reform

model_after.allocate()
model_after.solve()
s_forecast = model_after.sim.s_total

true_data_outofsample = model.data.moments_after
true_data_insample = model.data.moments_before
mse_eta1_outofsample = np.mean((true_data_outofsample - s_forecast)**2)
mse_eta1_insample = np.mean((true_data_insample - sim)**2)

# Now plotting s_forecast
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, s_forecast, label='After Reform', color='maroon')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
#Replicating figure 7(b) from the paper
after = model_new.data.moments_after
before = model_new.data.moments_before

time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, sim[:model.par.T_sim], color='Blue', label='Estimated hazard, Before', linestyle='--')
plt.plot((time+1)*15, s_forecast, label='Estimated hazard, After', color='Red', linestyle='--')
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='Blue')
plt.plot((time+1)*15, after, label='Actual hazard, After', color='Red')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.title('Real and estimated hazard rates of the reference denpendence model')
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %% [markdown]
# # Model with **NO** reference dependence (standard model)

# %%
# # model_new = deepcopy(model)

# model_new.par.eta = 0.0     # Removes reference dependence
# # model_new.par.full_sample_estimation = True
# model_new.allocate()

# est_par = ['gamma', 'cost1', 'cost2', 'type_shares1', 'Welfare'] # Parameters to estimate
# theta0 = [0.2, 84, 310, 0.4, 0.1] # Initial guesses
# bounds = [(0.01, 50.0), (0.0, model_new.par.cost2), (model_new.par.cost1,700), (0,1), (0,model.par.b3)] # Bounds for the parameters

# est = method_simulated_moments(model_new, est_par,theta0,bounds,weight=False)

# print("Optimization Results:")
# print("---------------------")
# print(f'{"Parameter":<15} {"Estimate":<15}')
# for param, estimate in zip(est_par, est.x):
#     print(f'{param:<15} {estimate:>15.3f}')
# print(f'Objective:               {est.fun:.4f}')
# print(f'Number of iterations:    {est.nit}')

# %%
model_new.par.eta = 0.0     # Removes reference dependence
model_new.par.types = 3    # Allow for heterogeneity
# model_new.par.full_sample_estimation = True
model_new.allocate()

est_par = ['delta','gamma', 'cost1', 'cost2', 'cost3', 'type_shares1', 'type_shares3', 'HTM_share'] # Parameters to estimate
theta0 = [0.9, 0.9, 84, 242, 310, 0.4, 0, 0.5] # Initial guesses
bounds = [(0.0,1.0), (0, 50.0), (0.0, model_new.par.cost2), (model_new.par.cost1,model_new.par.cost3), (model_new.par.cost2,700.0), (0,1), (0,1-model_new.par.type_shares1), (0.0,1.0)] # Bounds for the parameters

est = method_simulated_moments(model_new, est_par,theta0,bounds,weight=False)

print("Optimization Results:")
print("---------------------")
print(f'{"Parameter":<15} {"Estimate":<15}')
for param, estimate in zip(est_par, est.x):
    print(f'{param:<15} {estimate:>15.3f}')
print(f'Objective:               {est.fun:.4f}')
print(f'Number of iterations:    {est.nit}')
# Out:
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:64: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[0] = (s/par.cost1)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:65: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[1] = (s/par.cost2)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Funcs.py:66: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[2] = (s/par.cost3)**(1/par.gamma)
# Error at t=42, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.9358099366097007
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9358099366097007
#        x: -0.8633368395100072
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=40, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=40, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=40, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=39, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=39, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=39, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=38, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=38, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=38, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=37, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=37, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=37, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=36, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=36, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=36, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=35, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=35, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=35, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=34, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=34, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=34, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=33, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=33, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=33, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=32, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=32, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=32, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=31, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=31, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=31, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=30, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=30, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=30, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=29, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=29, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=29, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=28, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=28, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=28, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=27, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=27, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=27, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=26, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=26, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=26, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=25, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=25, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=25, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=25, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=25, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=25, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=25, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=25, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=25, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=25, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=24, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8505758630683232
#      nit: 21
#     nfev: 21
# Error at t=24, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8121834995639791
#      nit: 22
#     nfev: 22
# Error at t=24, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7737911360596348
#      nit: 23
#     nfev: 23
# Error at t=24, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7353987725552907
#      nit: 24
#     nfev: 24
# Error at t=24, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6970064090509465
#      nit: 24
#     nfev: 24
# Error at t=24, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6586140455466024
#      nit: 24
#     nfev: 24
# Error at t=24, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202216820422581
#      nit: 25
#     nfev: 25
# Error at t=24, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581829318537914
#      nit: 25
#     nfev: 25
# Error at t=24, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=24, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=23, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8369252449334452
#      nit: 22
#     nfev: 22
# Error at t=23, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7985328814291011
#      nit: 23
#     nfev: 23
# Error at t=23, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7601405179247569
#      nit: 23
#     nfev: 23
# Error at t=23, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7217481544204127
#      nit: 24
#     nfev: 24
# Error at t=23, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6833557909160686
#      nit: 24
#     nfev: 24
# Error at t=23, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6449634274117244
#      nit: 24
#     nfev: 24
# Error at t=23, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6065710639073802
#      nit: 25
#     nfev: 25
# Error at t=23, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5681787004030361
#      nit: 25
#     nfev: 25
# Error at t=23, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=23, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=22, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8369252449334452
#      nit: 22
#     nfev: 22
# Error at t=22, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7985328814291011
#      nit: 23
#     nfev: 23
# Error at t=22, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7601405179247569
#      nit: 23
#     nfev: 23
# Error at t=22, i_a=3
# ...
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7072443726521049
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6688520091477608
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6304596456434166
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920672821390724
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       7 theta0 = [0.9, 0.9, 84, 242, 310, 0.4, 0, 0.5] # Initial guesses
#       8 bounds = [(0.0,1.0), (0, 50.0), (0.0, model_new.par.cost2), (model_new.par.cost1,model_new.par.cost3), (model_new.par.cost2,700.0), (0,1), (0,1-model_new.par.type_shares1), (0.0,1.0)] # Bounds for the parameters
# ---> 10 est = method_simulated_moments(model_new, est_par,theta0,bounds,weight=False)
#      12 print("Optimization Results:")
#      13 print("---------------------")
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\estimation.py:36, in method_simulated_moments(model, est_par, theta0, bounds, weight)
#      33 if model.par.full_sample_estimation == True:
#      34     # Estimate using the full sample
#      35     obj_fun = lambda x: sum_squared_diff_moments_before_and_after(x,model,est_par,weight)
# ---> 36     res = minimize(obj_fun,theta0, method='SLSQP', bounds = bounds)
#      37 else:
#      38     # Estimate using only the before reform
#      39     obj_fun = lambda x: sum_squared_diff_moments(x,model,est_par,weight)
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_minimize.py:705, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     702     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     703                             **options)
#     704 elif meth == 'slsqp':
# --> 705     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     706                           constraints, callback=callback, **options)
#     707 elif meth == 'trust-constr':
#     708     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     709                                        bounds, constraints,
#     710                                        callback=callback, **options)
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_slsqp_py.py:432, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     429     c = _eval_constraint(x, cons)
#     431 if mode == -1:  # gradient evaluation required
# --> 432     g = append(wrapped_grad(x), 0.0)
#     433     a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     435 if majiter > majiter_prev:
#     436     # call callback if major iteration has incremented
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_optimize.py:346, in _clip_x_for_func.<locals>.eval(x)
#     344 def eval(x):
#     345     x = _check_clip_x(x, bounds)
# --> 346     return func(x)
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_differentiable_functions.py:273, in ScalarFunction.grad(self, x)
#     271 if not np.array_equal(x, self.x):
#     272     self._update_x_impl(x)
# --> 273 self._update_grad()
#     274 return self.g
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\estimation.py:35, in method_simulated_moments.<locals>.<lambda>(x)
#      31 assert (len(est_par)==len(theta0)), 'Number of parameters and initial values do not match'
#      33 if model.par.full_sample_estimation == True:
#      34     # Estimate using the full sample
# ---> 35     obj_fun = lambda x: sum_squared_diff_moments_before_and_after(x,model,est_par,weight)
#      36     res = minimize(obj_fun,theta0, method='SLSQP', bounds = bounds)
#      37 else:
#      38     # Estimate using only the before reform
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\estimation.py:96, in sum_squared_diff_moments_before_and_after(theta, model, est_par, weight)
#      94     moments_before_model = model.solve_ConSav()
#      95 else:
# ---> 96     moments_before_model = model.solve()
#      98 # Solve model after
#      99 par.b1 = 342.0/675.0
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Model.py:294, in ReferenceDependenceClass.solve(self)
#     292 	sim_s = self.solve_HTM()
#     293 else:
# --> 294 	sim_s_consav = self.solve_ConSav()
#     295 	sim_s_htm = self.solve_HTM()
#     296 	sim_s = self.par.HTM_share*sim_s_htm + (1-self.par.HTM_share)*sim_s_consav
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\Model.py:278, in ReferenceDependenceClass.solve_ConSav(self)
#     276 """ solve the model for Consumption-Saving agent"""
#     277 value_function_employment_ConSav(self.par, self.sol)
# --> 278 solve_search_and_consumption_ConSav(self.par, self.sol)
#     279 sim_search_effort_ConSav(self.par, self.sol, self.sim)
#     280 sim_s = self.sim.s_total
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\solve_consumption_saving.py:295, in solve_search_and_consumption_ConSav(par, sol)
#     293 upper_bound = min(upper_bound, par.A_0)
#     294 # Call optimizer
# --> 295 result = minimize_scalar(objective_function_ti, bounds=(lower_bound, upper_bound), args=(par, t, V_u[type, t+1,:], type), method='bounded')
#     297 # Extract optimal a_next
#     298 if result.success:
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_minimize.py:913, in minimize_scalar(fun, bracket, bounds, args, method, tol, options)
#     910     if bounds is None:
#     911         raise ValueError('The `bounds` parameter is mandatory for '
#     912                          'method `bounded`.')
# --> 913     return _minimize_scalar_bounded(fun, bounds, args, **options)
#     914 elif meth == 'golden':
#     915     return _minimize_scalar_golden(fun, bracket, args, **options)
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\optimize\_optimize.py:2266, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2264 si = np.sign(rat) + (rat == 0)
#    2265 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2266 fu = func(x, *args)
#    2267 num += 1
#    2268 fmin_data = (num, x, fu)
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\old_version\solve_consumption_saving.py:280, in solve_search_and_consumption_ConSav.<locals>.objective_function_ti(a_next, par, t, V_u_next, type)
#     278 V_e_next_interp = interp1d(par.a_grid, par.V_e_t_a[t+1, :])    # Interpolate value of getting employed next period
#     279 V_e_next = V_e_next_interp(a_next)                                  # Value of getting employed next period
# --> 280 V_u_next_interp = interp1d(par.a_grid, V_u_next)                    # Interpolate value of unemployment next period
#     281 V_u_next = V_u_next_interp(a_next)                                  # Value of unemployment next period
#     282 s = inv_marg_cost(par, par.delta*(V_e_next-V_u_next))[type]         # Search effort
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\interpolate\_interpolate.py:511, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     508 y = array(y, copy=self.copy)
#     510 if not assume_sorted:
# --> 511     ind = np.argsort(x, kind="mergesort")
#     512     x = x[ind]
#     513     y = np.take(y, ind, axis=axis)
#
# File <__array_function__ internals>:200, in argsort(*args, **kwargs)
#
# File c:\Users\marti\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:1146, in argsort(a, axis, kind, order)
#    1038 @array_function_dispatch(_argsort_dispatcher)
#    1039 def argsort(a, axis=-1, kind=None, order=None):
#    1040     """
#    1041     Returns the indices that would sort an array.
#    1042
#    (...)
#    1144
#    1145     """
# -> 1146     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File c:\Users\marti\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
model_new.solve()
sim_new = model_new.sim.s_total

time = np.linspace(0, model_new.par.T_sim, model_new.par.T_sim)
plt.plot((time+1)*15, sim_new[:], label='Before Reform', color='navy') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
model_new.par.b1 = 342.0/675.0      # Value after reform
model_new.par.b2 = 171.0/675.0      # Value after reform

model_new.allocate()
model_new.solve()
s_forecast_new = model_new.sim.s_total

# Now plotting s_forecast
time = np.linspace(0, model_new.par.T_sim, model_new.par.T_sim)
plt.plot((time+1)*15, s_forecast_new, label='After Reform', color='maroon')
plt.plot((time+1)*15, sim_new[:], label='Before Reform', color='navy') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
#Replicating figure 7(a) from the paper
after = model_new.data.moments_after
before = model_new.data.moments_before

time = np.linspace(0, model_new.par.T_sim, model_new.par.T_sim)
plt.plot((time+1)*15, sim_new, color='Blue', label='Estimated hazard, Before', linestyle='--')
plt.plot((time+1)*15, s_forecast_new, label='Estimated hazard, After', color='Red', linestyle='--')
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='Blue')
plt.plot((time+1)*15, after, label='Actual hazard, After', color='Red')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.title('Real and estimated hazard rates of the standard model')
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %% [markdown]
# # **Comparison of the standard model and reference dependence**
# ### Through the Mean Square Error

# %%
true_data_outofsample = model_new.data.moments_after
true_data_insample = model_new.data.moments_before

# Get the mean square errors
mse_eta0_outofsample = np.mean((true_data_outofsample - s_forecast_new)**2)
mse_eta0_insample = np.mean((true_data_insample - sim_new)**2)

# Comparison out of sample
comparison1 = "smaller" if mse_eta1_outofsample < mse_eta0_outofsample else "bigger" if mse_eta1_outofsample > mse_eta0_outofsample else "equal"
comparison2 = "WITH reference dependence" if mse_eta1_outofsample < mse_eta0_outofsample else "WITHOUT reference dependence" 

# Comparison in sample
comparison3 = "smaller" if mse_eta1_insample < mse_eta0_insample else "bigger" if mse_eta1_insample > mse_eta0_insample else "equal"
comparison4 = "WITH reference dependence" if mse_eta1_insample < mse_eta0_insample else "WITHOUT reference dependence"


print("Before the reform: ")
print("-" * 100)
print(f"The mean square error from the model \033[1mwith\033[0m reference dependence is {mse_eta1_insample}")
print(f"The mean square error from the model \033[1mwithout\033[0m reference dependence is {mse_eta0_insample}")
print(f"The mean square error for the model \033[1mwith\033[0m reference dependence is \033[1m{comparison3}\033[0m than the model without.")
print(f"Best model: \033[1m{comparison4}\033[0m.")
print("-" * 100)



print("After the reform:")
print("-" * 100)
print(f"The mean square error from the model \033[1mwith\033[0m reference dependence is {mse_eta1_outofsample}")
print(f"The mean square error from the model \033[1mwithout\033[0m reference dependence is {mse_eta0_outofsample}")
print(f"The mean square error for the model \033[1mwith\033[0m reference dependence is \033[1m{comparison1}\033[0m than the model without.")
print(f"Best model: \033[1m{comparison2}\033[0m.")
print("-" * 100)
# Out:
# Before the reform:
# ----------------------------------------------------------------------------------------------------
# The mean square error from the model with reference dependence is 0.00019815036745187694
# The mean square error from the model without reference dependence is 0.00010347354855527327
# The mean square error for the model with reference dependence is bigger than the model without.
# Best model: WITHOUT reference dependence.
# ----------------------------------------------------------------------------------------------------
# After the reform:
# ----------------------------------------------------------------------------------------------------
# The mean square error from the model with reference dependence is 9.984412418630722e-05
# The mean square error from the model without reference dependence is 7.885317507200398e-05
# The mean square error for the model with reference dependence is bigger than the model without.
# Best model: WITHOUT reference dependence.
# ----------------------------------------------------------------------------------------------------

# %%
after = model_new.data.moments_after

time = np.linspace(0, model_new.par.T_sim, model_new.par.T_sim)     # x-axis
plt.plot((time+1)*15, s_forecast_new, label='Standard model', color='salmon', linestyle='--')                     # Model with no reference dependence
plt.plot((time+1)*15, s_forecast, label='Reference dependence', color='crimson', linestyle='--')                         # Model with reference dependence
plt.plot((time+1)*15, after, label='Actual hazard, After', color='tan')                        # True data
# Make a vertical line at 90, 270 and 360
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.legend()
plt.title('Real and estimated hazard rates before the reform')
plt.show()

# %%
before = model_new.data.moments_before

time = np.linspace(0, model_new.par.T_sim, model_new.par.T_sim)     # x-axis
plt.plot((time+1)*15, sim_new, label='Standard model', color='salmon', linestyle='--')                            # Model with no reference dependence
plt.plot((time+1)*15, sim, label='Reference dependence', color='crimson', linestyle='--')                                # Model with reference dependence
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='tan')                           # True data
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.legend()
plt.title('Real and estimated hazard rates before the reform')
plt.show()
