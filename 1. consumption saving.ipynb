# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

from consumption_saving import *

# %%
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()

# %%
value_function_employment(model.par, model.sol)

# %%
model.sol.a_next_e[0,-1,0,:]
# Out:
# array([-6.18033989e-07, -6.18033989e-07])

# %%
print(np.shape(model.par.V_e_t_a))
model.par.V_e_t_a[0,0,0]
# Out:
# (2, 44, 2)
# array([-2.55953525e-05,  6.79246821e-01,  1.33788454e+00,  1.97217773e+00,
#         2.57743179e+00,  3.14759445e+00,  3.67467702e+00,  4.14782995e+00,
#         4.55179100e+00,  4.86411382e+00,  5.04980806e+00,  5.04980806e+00,
#         5.04980806e+00,  5.04980806e+00,  5.04980806e+00,  5.04980806e+00,
#         5.04980806e+00,  5.04980806e+00,  5.04980806e+00,  5.33154748e+00,
#         5.60592309e+00,  5.87159002e+00,  6.12682705e+00,  6.36937778e+00,
#         6.59619513e+00,  6.88107142e+00,  7.14190420e+00,  7.36812558e+00,
#         7.53995156e+00,  7.61121893e+00,  7.67742426e+00,  7.73741942e+00,
#         7.78953377e+00,  7.83112844e+00,  7.85744575e+00,  7.85744575e+00,
#         7.85744575e+00,  7.85744575e+00,  7.85744575e+00,  7.85744575e+00,
#         7.85744575e+00,  7.85744575e+00,  7.85744575e+00,  7.85744575e+00])

# %%
print(model.sol.a_next_e[0,-1,0,:])
# Out:
# [-6.18033989e-07 -6.18033989e-07]

# %%
print(np.shape(model.par.V_e))
model.par.V_e[0,-1,:,-1]
# Out:
# (2, 44, 20, 2)
# array([7.85748906e+00, 5.87194453e+00, 4.37971414e+00, 3.21378795e+00,
#        2.29214962e+00, 1.56600926e+00, 1.00303919e+00, 5.80271502e-01,
#        2.80568019e-01, 9.06663929e-02, 1.08490896e-05, 9.66766305e-06,
#        8.48029965e-06, 7.28696960e-06, 6.08764292e-06, 4.88228947e-06,
#        3.67087896e-06, 2.45338097e-06, 1.22976490e-06, 0.00000000e+00])

# %%
V_u, s = unemployment_ss(model.par, -1, 1, 0)
print(V_u, s)
# Out:
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=364.9949245522157, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0
# -91.71902214269537 0.27750457843147197

# %%
for i_a in range(len(model.par.a_grid)):
    V_u, s = unemployment_ss(model.par, -1, i_a, 1)
    print(V_u, s)
# Out:
# Initial interval: a=-1, fa=-2.009903144065364, b=1, fb=-2.019903144065364
# Trying interval: factor_a=-500.0, fa=193.46943327772487, factor_b=0.0, fb=-2.014903144065364
# Valid interval found: a=-500.0, b=0.0
# -253.01623228813267 0.051033980266288095
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=193.469472182549, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0
# -253.0161906487654 0.051033985703098333

# %%
solve_search_and_consumption(model.par, model.sol)
# Out:
# Initial interval: a=-1, fa=-2.009903144065364, b=1, fb=-2.019903144065364
# Trying interval: factor_a=-500.0, fa=364.9948856473917, factor_b=0.0, fb=-2.014903144065364
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.009903144065364, b=1, fb=-2.019903144065364
# Trying interval: factor_a=-500.0, fa=364.9948856473917, factor_b=0.0, fb=-2.014903144065364
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=364.9949245522157, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=364.9949245522157, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.009903144065364, b=1, fb=-2.019903144065364
# Trying interval: factor_a=-500.0, fa=193.46943327772487, factor_b=0.0, fb=-2.014903144065364
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.009903144065364, b=1, fb=-2.019903144065364
# Trying interval: factor_a=-500.0, fa=193.46943327772487, factor_b=0.0, fb=-2.014903144065364
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=193.469472182549, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0
# Initial interval: a=-1, fa=-2.0099030205422648, b=1, fb=-2.0199030205422646
# Trying interval: factor_a=-500.0, fa=193.469472182549, factor_b=0.0, fb=-2.0149030205422647
# Valid interval found: a=-500.0, b=0.0

# %%
model.sol.s[0,-3,:]
# Out:
# array([0.27750467, 0.27750467])

# %%
import matplotlib.pyplot as plt

# Assuming solve_search_effort returns a tuple where the first element is the time array and the second element is the search effort array
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,0])
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:])
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next')
plt.grid(True)
plt.show()

# %%
model1 = model.copy()
# model1.par.L = -0.00
# model1.par.a_grid = np.linspace(model1.par.L, model1.par.A_0, 20)
model1.par.euler = False

# %%
# value_function_employment(model1.par, model1.sol)

# %%
# solve_search_and_consumption(model1.par, model1.sol)

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next[0,0,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next unemployed')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next_e[-0,1,3,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next_e[-1,3,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next employed')
# plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.c_e[0,-1,5,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.c_e[-1,5,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('c')
plt.title('consumption employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
time = np.linspace(0, model1.par.N + model1.par.M, model1.par.N + model1.par.M)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,-1,:,18])
# plt.plot(time, model1.par.V_e[-1,:,18])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/sophiebune/Desktop/Dynamic-programming-project/1. consumption saving.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell:/Users/sophiebune/Desktop/Dynamic-programming-project/1.%20consumption%20saving.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> time = np.linspace(0, model1.par.N + model1.par.M, model1.par.N + model1.par.M)
#       <a href='vscode-notebook-cell:/Users/sophiebune/Desktop/Dynamic-programming-project/1.%20consumption%20saving.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
# ----> <a href='vscode-notebook-cell:/Users/sophiebune/Desktop/Dynamic-programming-project/1.%20consumption%20saving.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(time, model.par.V_e[0,-1,:,18])
#
# IndexError: index 18 is out of bounds for axis 3 with size 2

# %%
time = np.linspace(0, model1.par.T, model1.par.T)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,:,3,3], label='Euler')
# plt.plot(time, model1.par.V_e[:,3,3], label='VFI')
plt.legend()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,-1], label='Euler')
# plt.plot(time, model1.sol.s[:model1.par.T,0], label='VFI')
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
solve_forward(model.par, model.sol, model.sim,0)

# %%
# solve_forward(model1.par, model1.sol, model1.sim)

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:model.par.T], label='Euler')
# plt.plot(time, model1.sim.s[:model.par.T], label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:], label='Euler')
plt.plot(time, model.sim.a_next[0,:], label='Euler')
# plt.plot(time, model1.sim.s, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.c[0,:], label='Euler')
# plt.plot(time, model.sim.a_next, label='Euler')
# plt.plot(time, model1.sim.c, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('consumption and assets')
plt.title('Consumption and assets over Time unemployed' )
plt.grid(True)
plt.legend()
plt.show()

# %%
# solve_forward_employment(model.par, model.sol, model.sim)

# %%
# solve_forward_employment(model1.par, model1.sol, model1.sim)

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.a_e[-1,:], label='Euler')
# plt.plot(time, model1.sim.a_e[-1,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('next assets')
# plt.title('Assetts over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.c_e[10,:], label='Euler')
# plt.plot(time, model1.sim.c_e[10,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('consumption')
# plt.title('Consumption over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
sim_search_effort(model.par, model.sol, model.sim)

# %%
# plot sim_search_effort
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot(time, model.sim.s[0,:model.par.T_sim], label='sim')
plt.plot(time, model.sim.s_total[:model.par.T_sim], label='sim total')
plt.legend()
