# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

from consumption_saving import *

# %%
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/Moments_hazard.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 from Model import ReferenceDependenceClass
# ----> 2 model = ReferenceDependenceClass()
#
# File c:\users\marti\onedrive - university of copenhagen\økonomi\python\econmodel\EconModel\EconModel.py:67, in EconModelClass.__init__(self, name, load, from_dict, skip, **kwargs)
#      65 # iii setup
#      66 assert hasattr(self,'setup'), 'the model must have defined an .setup() method'
# ---> 67 self.setup()
#      69 if load:
#      70
#      71     # iv. create
#      72     self.allocate()
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\Model.py:29, in ReferenceDependenceClass.setup(self)
#      26 data = self.data
#      27 # Data
#      28 # get the data
# ---> 29 data.data = loadmat('Data/Moments_hazard.mat')
#      31 # Access the 'Moments' table
#      32 data.moments = data.data['Moments']
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\io\matlab\_mio.py:225, in loadmat(file_name, mdict, appendmat, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)
#     222     3.14159265+3.14159265j])
#     223 """
#     224 variable_names = kwargs.pop('variable_names', None)
# --> 225 with _open_file_context(file_name, appendmat) as f:
#     226     MR, _ = mat_reader_factory(f, **kwargs)
#     227     matfile_dict = MR.get_variables(variable_names)
#
# File c:\Users\marti\Anaconda\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\marti\Anaconda\lib\site-packages\scipy\io\matlab\_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/Moments_hazard.mat'

# %%
value_function_employment(model.par, model.sol)

# %%
model.sol.a_next_e[0,-1,0,:]
# Out:
# array([-1.77160790e+00, -1.68421194e+00, -1.59231119e+00, -1.49788245e+00,
#        -1.40318269e+00, -1.30834287e+00, -1.21347198e+00, -1.11868607e+00,
#        -1.02414327e+00, -9.30217765e-01, -8.42106415e-01, -7.55013589e-01,
#        -6.60359866e-01, -5.64938927e-01, -4.69259492e-01, -3.73520020e-01,
#        -2.77867924e-01, -1.82490348e-01, -8.78338089e-02, -4.03469594e-06])

# %%
print(np.shape(model.par.V_e_t_a))
model.par.V_e_t_a[0,:,0]
# Out:
# (2, 44, 20)
# array([-10.54006708,  -7.76312098,  -5.29270652,  -3.14875385,
#         -2.00349444,  -1.43037954,  -0.9032969 ,  -0.43014399,
#         -0.02618294,   0.28613988,   0.47183413,   0.47183413,
#          0.47183413,   0.47183413,   0.47183413,   0.47183413,
#          0.47183413,   0.47183413,   0.47183413,   0.76948673,
#          1.0496325 ,   1.31598444,   1.57129145,   1.81384216,
#          2.04065955,   2.2474705 ,   2.42797639,   2.57222341,
#          2.66273742,   2.66273742,   2.66273742,   2.66273742,
#          2.66273742,   2.66273742,   2.66273742,   2.66273742,
#          2.66273742,   2.66273742,   2.66273742,   2.66273742,
#          2.66273742,   2.66273742,   2.66273742,   2.66273742])

# %%
print(np.shape(model.par.V_e))
model.par.V_e[0,-1,:,-1]
# Out:
# (2, 44, 20, 20)
# array([ 7.21816625e+00,  5.46698709e+00,  4.10920709e+00,  3.03106949e+00,
#         2.17017823e+00,  1.48713004e+00,  9.54810960e-01,  5.53446056e-01,
#         2.67992950e-01,  8.66423924e-02, -1.14290234e-04, -1.01917568e-04,
#        -8.94699537e-05, -7.69453247e-05, -6.43412499e-05, -5.16548262e-05,
#        -3.88825231e-05, -2.60199572e-05, -1.30615515e-05,  0.00000000e+00])

# %%
V_u,s = unemployment_ss(model.par, -1,-1,0)
print(V_u,s)
# Out:
# 3.97353127030202 2.1306317702972644

# %%
solve_search_and_consumption(model.par, model.sol)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 solve_search_and_consumption(model.par, model.sol)
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\consumption_saving.py:280, in solve_search_and_consumption(par, sol)
#     277     a_next[type,t,i_a] = par.a_grid[i_a]
#     278     c[type,t,i_a] = par.a_grid[i_a] + par.income_u[t] - par.a_grid[i_a] / (par.R)
# --> 280 else: # Previous periods. Chech that debt converges to par.L before stationary state when solving forward
#     281     def objective_function_ti(a_next, par,t,V_u_next, type):
#     283         income = par.income_u[t]
#
# File c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\consumption_saving.py:250, in unemployment_ss(par, t, i_a, type)
#     248 # Perform the root finding
#     249 V_u = brentq(bellman_difference, a, b)
# --> 250 s = inv_marg_cost(par, par.delta * (V_e - V_u))[type]
#     252 return V_u, s
#
# ValueError: Could not find a valid interval where the function has different signs.

# %%
model.sol.s[0,-3,:]
# Out:
# array([0.43507584, 0.4350759 , 0.4295147 , 0.40868019, 0.40213197,
#        0.39147114, 0.38502188, 0.38046113, 0.37502636, 0.37356751,
#        0.37074133, 0.37038764, 0.36992637, 0.36965367, 0.36938112,
#        0.36910871, 0.36883645, 0.36856433, 0.36829235, 0.36802053])

# %%
import matplotlib.pyplot as plt

# Assuming solve_search_effort returns a tuple where the first element is the time array and the second element is the search effort array
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,0])
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:])
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next')
plt.grid(True)
plt.show()

# %%
model1 = model.copy()
# model1.par.L = -0.00
# model1.par.a_grid = np.linspace(model1.par.L, model1.par.A_0, 20)
model1.par.euler = False

# %%
# value_function_employment(model1.par, model1.sol)

# %%
# solve_search_and_consumption(model1.par, model1.sol)

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next[0,0,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next unemployed')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next_e[-0,1,3,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next_e[-1,3,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next employed')
# plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.c_e[0,-1,5,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.c_e[-1,5,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('c')
plt.title('consumption employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
time = np.linspace(0, model1.par.N + model1.par.M, model1.par.N + model1.par.M)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,-1,:,18])
# plt.plot(time, model1.par.V_e[-1,:,18])

# %%
time = np.linspace(0, model1.par.T, model1.par.T)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,:,3,3], label='Euler')
# plt.plot(time, model1.par.V_e[:,3,3], label='VFI')
plt.legend()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,0], label='Euler')
# plt.plot(time, model1.sol.s[:model1.par.T,0], label='VFI')
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
solve_forward(model.par, model.sol, model.sim,0)

# %%
# solve_forward(model1.par, model1.sol, model1.sim)

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:model.par.T], label='Euler')
# plt.plot(time, model1.sim.s[:model.par.T], label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:], label='Euler')
plt.plot(time, model.sim.a_next[0,:], label='Euler')
# plt.plot(time, model1.sim.s, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.c[0,:], label='Euler')
# plt.plot(time, model.sim.a_next, label='Euler')
# plt.plot(time, model1.sim.c, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('consumption and assets')
plt.title('Consumption and assets over Time unemployed' )
plt.grid(True)
plt.legend()
plt.show()

# %%
# solve_forward_employment(model.par, model.sol, model.sim)

# %%
# solve_forward_employment(model1.par, model1.sol, model1.sim)

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.a_e[-1,:], label='Euler')
# plt.plot(time, model1.sim.a_e[-1,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('next assets')
# plt.title('Assetts over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.c_e[10,:], label='Euler')
# plt.plot(time, model1.sim.c_e[10,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('consumption')
# plt.title('Consumption over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
sim_search_effort(model.par, model.sol, model.sim)

# %%
# plot sim_search_effort
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot(time, model.sim.s[0,:model.par.T_sim], label='sim')
plt.plot(time, model.sim.s_total[:model.par.T_sim], label='sim total')
plt.legend()
