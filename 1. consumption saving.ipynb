# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from consumption_saving import *

# %%
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()

# %%
value_function_employment(model.par, model.sol)

# %%
model.sol.a_next_e[0,-1,0,:]
# Out:
# array([-1.77546480e+00, -1.68421182e+00, -1.60005542e+00, -1.50644647e+00,
#        -1.41179209e+00, -1.31672144e+00, -1.22144608e+00, -1.12606084e+00,
#        -1.03062764e+00, -9.35234263e-01, -8.42106270e-01, -7.55013153e-01,
#        -6.60359338e-01, -5.64938254e-01, -4.69258546e-01, -3.73521105e-01,
#        -2.77867828e-01, -1.82489609e-01, -8.78332191e-02, -4.03469594e-06])

# %%
print(np.shape(model.par.V_e_t_a))
model.par.V_e_t_a[0,:,0]
# Out:
# (1, 44, 20)
# array([-6.61056634e+00, -5.12215073e+00, -3.81829549e+00, -2.71010550e+00,
#        -1.97881685e+00, -1.40842540e+00, -8.81342835e-01, -4.08189930e-01,
#        -4.22889207e-03,  3.08093934e-01,  4.93788175e-01,  4.93788175e-01,
#         4.93788175e-01,  4.93788175e-01,  4.93788175e-01,  4.93788175e-01,
#         4.93788175e-01,  4.93788175e-01,  4.93788175e-01,  7.94151708e-01,
#         1.06947463e+00,  1.33534696e+00,  1.59058385e+00,  1.83313463e+00,
#         2.05995195e+00,  2.26676296e+00,  2.44726885e+00,  2.59151587e+00,
#         2.68202988e+00,  2.68202988e+00,  2.68202988e+00,  2.68202988e+00,
#         2.68202988e+00,  2.68202988e+00,  2.68202988e+00,  2.68202988e+00,
#         2.68202988e+00,  2.68202988e+00,  2.68202988e+00,  2.68202988e+00,
#         2.68202988e+00,  2.68202988e+00,  2.68202988e+00,  2.68202988e+00])

# %%
print(np.shape(model.par.V_e))
model.par.V_e[0,-1,:,-1]
# Out:
# (1, 44, 20, 20)
# array([ 7.21824199e+00,  5.46706321e+00,  4.10928360e+00,  3.03114638e+00,
#         2.17025551e+00,  1.48720771e+00,  9.54888879e-01,  5.53524390e-01,
#         2.68071833e-01,  8.67188493e-02, -4.52791164e-05, -4.03939909e-05,
#        -3.54763586e-05, -3.05249986e-05, -2.55384639e-05, -2.05150125e-05,
#        -1.54525112e-05, -1.03482946e-05, -5.19895333e-06,  0.00000000e+00])

# %%
V_u, s = unemployment_ss(model.par, -1, 1, 0)
print(V_u, s)
# Out:
# -96.36356499979043 0.2658247235936313
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\Funcs.py:77: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[0] = (s/par.cost1)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\Funcs.py:78: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[1] = (s/par.cost2)**(1/par.gamma)
# c:\Users\marti\OneDrive - University of Copenhagen\Økonomi\8. semester\Dynamic Prog\Dynamic-programming-project\Funcs.py:79: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[2] = (s/par.cost3)**(1/par.gamma)

# %%
for i_a in range(len(model.par.a_grid)):
    V_u, s = unemployment_ss(model.par, -1, i_a, 0)
    print(V_u, s)
# Out:
# -96.67318024382467 0.2674027198332603
# -96.36356499979043 0.2658247235936313
# -96.06491199009062 0.26424310988312266
# -95.76975587703842 0.2626641297969937
# -95.47768305049206 0.2610880909844149
# -95.18849045738816 0.25951512413276256
# -94.90204652632768 0.2579453001320685
# -94.61825285402419 0.25637866234030754
# -94.33702984988338 0.25481523866450556
# -94.05831195354261 0.25325504557205997
# -93.78205569167211 0.25169808124851056
# -93.51317087078345 0.25014015210361656
# -93.24673601310938 0.24858538234624836
# -92.98251334997545 0.247033935735518
# -92.72039010236368 0.24548587073448092
# -92.46029947074084 0.24394120727828694
# -92.20220117430097 0.24239994319839211
# -91.94607846669568 0.24086205670742641
# -91.69194844091297 0.23932749761233246
# -91.4399121003436 0.23779614474884936

# %%
solve_search_and_consumption(model.par, model.sol)

# %%
model.sol.s[0,-3,:]
# Out:
# array([0.26740553, 0.25864167, 0.23291049, 0.23220727, 0.21734304,
#        0.21675358, 0.20857197, 0.20791249, 0.20349954, 0.20286421,
#        0.20072539, 0.1995926 , 0.19827076, 0.19695361, 0.19563357,
#        0.19432539, 0.19303926, 0.1915944 , 0.190155  , 0.18866998])

# %%
import matplotlib.pyplot as plt

# Assuming solve_search_effort returns a tuple where the first element is the time array and the second element is the search effort array
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,0])
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:])
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next')
plt.grid(True)
plt.show()

# %%
model1 = model.copy()
# model1.par.L = -0.00
# model1.par.a_grid = np.linspace(model1.par.L, model1.par.A_0, 20)
model1.par.euler = False

# %%
# value_function_employment(model1.par, model1.sol)

# %%
# solve_search_and_consumption(model1.par, model1.sol)

# %%
plt.plot(model.par.a_grid, model.sol.a_next[0,0,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next[0,0,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next unemployed')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.a_next_e[-0,1,3,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.a_next_e[-1,3,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next employed')
# plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.c_e[0,-1,5,:], label='Euler')
# plt.plot(model1.par.a_grid, model1.sol.c_e[-1,5,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('c')
plt.title('consumption employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
time = np.linspace(0, model1.par.N + model1.par.M, model1.par.N + model1.par.M)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,-1,:,18])
# plt.plot(time, model1.par.V_e[-1,:,18])

# %%
time = np.linspace(0, model1.par.T, model1.par.T)
n = np.linspace(0, model1.par.N+model.par.M, model1.par.N+model.par.M)
plt.plot(time, model.par.V_e[0,:,3,3], label='Euler')
# plt.plot(time, model1.par.V_e[:,3,3], label='VFI')
plt.legend()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sol.s[0,:model.par.T,-1], label='Euler')
# plt.plot(time, model1.sol.s[:model1.par.T,0], label='VFI')
plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
solve_forward(model.par, model.sol, model.sim,0)

# %%
# solve_forward(model1.par, model1.sol, model1.sim)

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:model.par.T], label='Euler')
# plt.plot(time, model1.sim.s[:model.par.T], label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.s[0,:], label='Euler')
plt.plot(time, model.sim.a_next[0,:], label='Euler')
# plt.plot(time, model1.sim.s, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('Search Effort')
plt.title('Search Effort over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
time = np.linspace(0, model.par.T, model.par.T)
plt.plot(time, model.sim.c[0,:], label='Euler')
# plt.plot(time, model.sim.a_next, label='Euler')
# plt.plot(time, model1.sim.c, label='VFI')
# plt.plot(time, model1.sim.a_next, label='VFI')

plt.xlabel('Time')
plt.ylabel('consumption and assets')
plt.title('Consumption and assets over Time unemployed' )
plt.grid(True)
plt.legend()
plt.show()

# %%
# solve_forward_employment(model.par, model.sol, model.sim)

# %%
# solve_forward_employment(model1.par, model1.sol, model1.sim)

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.a_e[-1,:], label='Euler')
# plt.plot(time, model1.sim.a_e[-1,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('next assets')
# plt.title('Assetts over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
# time = np.linspace(0, model.par.N+model.par.M, model.par.N+model.par.M)
# plt.plot(time, model.sim.c_e[10,:], label='Euler')
# plt.plot(time, model1.sim.c_e[10,:], label='VFI')


# plt.xlabel('Time')
# plt.ylabel('consumption')
# plt.title('Consumption over time after employment')
# plt.grid(True)
# plt.legend()
# plt.show()

# %%
sim_search_effort(model.par, model.sol, model.sim)

# %%
# plot sim_search_effort
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot(time, model.sim.s[0,:model.par.T_sim], label='sim')
plt.plot(time, model.sim.s_total[:model.par.T_sim], label='sim total')
plt.legend()
