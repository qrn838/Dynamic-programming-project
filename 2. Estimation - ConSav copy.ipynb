# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
from solve_consumption_saving import *
from copy import deepcopy
from estimation import *

# %load_ext autoreload
# %autoreload 2

# %pip install EconModel
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()
model.par.full_sample_estimation = True
model.allocate()
model_standard = deepcopy(model)    # Used later for standard model
model.par.model = 'ConSav'
model_standard.par.model = 'ConSav'

# %% [markdown]
# # **Estimating using the full sample** #
# (using hazard rates from both before and after the reform)

# %% [markdown]
# # Model with reference dependence

# %%
# Setup
model.par.eta = 1  # Reference dependence
model.par.types = 1  # No heterogeneity
model.par.euler = True
model.allocate()

# Estimation setup
est_par = ['delta', 'gamma', 'lambdaa', 'cost1'] # Parameters to estimate
theta0 = [0.95, 0.4, 2.0, 100.0]  # Initial guesses
bounds = [(0.5, 1), (0.001, 10.0), (0.0, 10.0), (0.0,500)] # Bounds for the parameters



# Random starting values:
model.par.noOfParams = len(est_par)
model.par.noSearchInits = 10
np.random.seed(180615)
est_best = np.inf

for i in range(model.par.noSearchInits):

    theta0 = [np.random.uniform(model.par.lb_delta, model.par.ub_delta),
              np.random.uniform(model.par.lb_gamma,model.par.ub_gamma),
              np.random.uniform(model.par.lb_lambdaa,model.par.ub_lambdaa),
              np.random.uniform(model.par.lb_c,model.par.ub_c)]

    
    try:
        # Perform the method of simulated moments
        est = method_simulated_moments(model, est_par, theta0, bounds, weight=True)

        # Check if the current estimate is better than the best estimate
        if est.fun < est_best:
            est_best = est.fun
            par = est.x
            nit = est.nit
            obj_ref = est_best

    except Exception as e:
        # Print the exception message and continue with the next iteration
        print(f"Iteration {i} failed with error: {e}")
        continue



# print("Optimization Results:")
# print("---------------------")
# print(f'{"Parameter":<15} {"Estimate":<15}')
# for param, estimate in zip(est_par, par):
#     print(f'{param:<15} {estimate:>15.3f}')
# print(f'Objective:               {est_best:.4f}')
# print(f'Number of iterations:    {nit}')
# Out:
# /Users/sophiebune/Desktop/Dynamic-programming-project/solve_consumption_saving.py:90: RuntimeWarning: divide by zero encountered in divide
#   par.V_e[t, n, :] = utility(par, sol.c_e[t, n, :], par.r_e_m[t, t+n])/ (1 - par.delta)
# /Users/sophiebune/Desktop/Dynamic-programming-project/solve_consumption_saving.py:90: RuntimeWarning: invalid value encountered in divide
#   par.V_e[t, n, :] = utility(par, sol.c_e[t, n, :], par.r_e_m[t, t+n])/ (1 - par.delta)
# /Users/sophiebune/Desktop/Dynamic-programming-project/Funcs.py:26: RuntimeWarning: divide by zero encountered in divide
#   mu = np.where(c >= r, 1/c * (1 + par.eta), 1/c * (1 + par.eta * par.lambdaa))
# /Users/sophiebune/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:701: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/sophiebune/Desktop/Dynamic-programming-project/solve_consumption_saving.py:185: RuntimeWarning: divide by zero encountered in divide
#   V_u = (utility(par, c, r) - cost(par,s)[i] + par.delta * (s * V_e)) / (1-par.delta*(1-s))
# /Users/sophiebune/Desktop/Dynamic-programming-project/Funcs.py:64: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[0] = (s/par.cost1)**(1/par.gamma)
# /Users/sophiebune/Desktop/Dynamic-programming-project/Funcs.py:65: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[1] = (s/par.cost2)**(1/par.gamma)
# /Users/sophiebune/Desktop/Dynamic-programming-project/Funcs.py:66: RuntimeWarning: invalid value encountered in scalar power
#   inv_c_marg[2] = (s/par.cost3)**(1/par.gamma)
# Error at t=14, i_a=1
# Error message: NaN result encountered.
# Current function value: 2.303345273050231
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.303345273050231
#        x: -0.8765591714412683
#      nit: 24
#     nfev: 24
# Error at t=13, i_a=0
# Error message: NaN result encountered.
# Current function value: 2.7965925669414364
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.7965925669414364
#        x: -0.8529394329810208
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=0
# Error message: NaN result encountered.
# Current function value: 3.1702107854903496
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.1702107854903496
#        x: -0.8382487803221236
#      nit: 23
#     nfev: 23
# Error at t=12, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.5515497438454157
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5515497438454157
#        x: -0.8382487041273841
#      nit: 25
#     nfev: 25
# Error at t=12, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.22408237822099714
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.22408237822099714
#        x: -0.8382490393329565
#      nit: 26
#     nfev: 26
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.033427956987749
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.033427956987749
#        x: -0.791245215962812
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.9259618610000655
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.9259618610000655
#        x: -0.8114926166026858
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.9144468506998122
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.9144468506998122
#        x: -0.7551219439597363
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=3
# Error message: NaN result encountered.
# Current function value: 1.7609072057458517
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.7609072057458517
#        x: -0.7551208172596878
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=4
# Error message: NaN result encountered.
# Current function value: 1.0587267463797732
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.0587267463797732
#        x: -0.7551223371770374
#      nit: 25
#     nfev: 25
# Error at t=7, i_a=2
# Error message: NaN result encountered.
# Current function value: 3.878146603611722
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.878146603611722
#        x: -0.8618609578014348
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: 8.18157650521021
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 8.18157650521021
#        x: -0.8864750293334723
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: 6.802885306277197
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.802885306277197
#        x: -0.8864750615502053
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.72659490946325
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.72659490946325
#        x: -0.8864750904492491
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=4, i_a=2
# Error message: NaN result encountered.
# Current function value: 4.260201595516756
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.260201595516756
#        x: -0.7260301985062682
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=5
# Error message: NaN result encountered.
# Current function value: 1.2108409797312287
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.2108409797312287
#        x: -0.7260284885810301
#      nit: 26
#     nfev: 26
# Error at t=4, i_a=6
# Error message: NaN result encountered.
# Current function value: 0.5056427867778672
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5056427867778672
#        x: -0.7260292166520315
#      nit: 26
#     nfev: 26
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=2
# Error message: NaN result encountered.
# Current function value: 4.677404954601281
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.677404954601281
#        x: -0.714123961980817
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=4
# Error message: NaN result encountered.
# Current function value: 2.388953700218887
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.388953700218887
#        x: -0.714123412003829
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=8
# Error message: NaN result encountered.
# Current function value: -0.04182553981793155
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.04182553981793155
#        x: -0.7141243018997044
#      nit: 26
#     nfev: 26
# Error at t=2, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=2, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=7
# Error message: NaN result encountered.
# Current function value: 1.4980417584797778
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.4980417584797778
#        x: -0.6723657510921166
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: 3.2029355834023367
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.2029355834023367
#        x: -0.6993492946608547
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=3
# Error message: NaN result encountered.
# Current function value: 4.558244989591071
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.558244989591071
#        x: -0.8669041651678379
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=1
# Error message: NaN result encountered.
# Current function value: 5.881518640289209
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.881518640289209
#        x: -0.8135522566080797
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: 6.120436211888457
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.120436211888457
#        x: -0.701895201534081
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=3
# Error message: NaN result encountered.
# Current function value: 4.138387120422475
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.138387120422475
#        x: -0.7018972995443306
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=5
# Error message: NaN result encountered.
# Current function value: 2.7284889725684005
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.7284889725684005
#        x: -0.7018958857965929
#      nit: 22
#     nfev: 22
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.718256650555638
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.718256650555638
#        x: -0.7865843507999347
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: 4.969388860614051
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.969388860614051
#        x: -0.7821219773664421
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.9020893139479274
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.9020893139479274
#        x: -0.7821215242705513
#      nit: 25
#     nfev: 25
# /Users/sophiebune/anaconda3/lib/python3.11/site-packages/scipy/optimize/_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.588072680683779
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.588072680683779
#        x: -0.8965818930447965
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.417859599688572
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.417859599688572
#        x: -0.8516236983556081
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.100854135970976
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.100854135970976
#        x: -0.8516234108345943
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.33334483765725004
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.33334483765725004
#        x: -0.7399488595837391
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.749602147909032
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.749602147909032
#        x: -0.7399478749958084
#      nit: 24
#     nfev: 24
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.588072915962809
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.588072915962809
#        x: -0.8965818930447965
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.4178597030093267
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.4178597030093267
#        x: -0.8516236983556081
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.1008545650850596
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.1008545650850596
#        x: -0.851623402276767
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.5191920001292211
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5191920001292211
#        x: -0.7399489703819523
#      nit: 25
#     nfev: 25
# Error at t=9, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.3333448363300307
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.3333448363300307
#        x: -0.7399488590064537
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.7496021470780051
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.7496021470780051
#        x: -0.7399478745505557
#      nit: 24
#     nfev: 24
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.588072678996644
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.588072678996644
#        x: -0.8965818930447965
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.4178595992114107
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.4178595992114107
#        x: -0.8516236983556081
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.1008541593254986
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.1008541593254986
#        x: -0.8516234102085912
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.3333448375734864
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.3333448375734864
#        x: -0.7399488595473146
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.7496021478400562
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.7496021478400562
#        x: -0.7399478749588724
#      nit: 24
#     nfev: 24
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.588072688259539
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.588072688259539
#        x: -0.8965818930447965
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.417859604565461
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.417859604565461
#        x: -0.8516236983556081
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.100854139795488
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.100854139795488
#        x: -0.8516234107698021
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.5191919976992372
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5191919976992372
#        x: -0.7399489710719719
#      nit: 25
#     nfev: 25
# Error at t=9, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.3333448376441623
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.3333448376441623
#        x: -0.7399488595780583
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.7496021479002397
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.7496021479002397
#        x: -0.7399478749911172
#      nit: 24
#     nfev: 24
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.588072680684965
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.588072680684965
#        x: -0.8965818930447965
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.417859599688882
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.417859599688882
#        x: -0.8516236983556081
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.100854135960035
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.100854135960035
#        x: -0.8516234108348898
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.33334483765729156
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.33334483765729156
#        x: -0.7399488595837572
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.749602147909067
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.749602147909067
#        x: -0.7399478749958273
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: 9.280354003925686
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 9.280354003925686
#        x: -0.8863079402210244
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=0
# Error message: NaN result encountered.
# Current function value: 3.1204474952513683
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.1204474952513683
#        x: -0.8757256740525168
#      nit: 24
#     nfev: 24
# Error at t=10, i_a=0
# Error message: NaN result encountered.
# Current function value: 4.700810533320263
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.700810533320263
#        x: -0.8142739255202107
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.2077147627360123
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.2077147627360123
#        x: -0.8142752807231496
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.345515220801284
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.345515220801284
#        x: -0.8620527238216404
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: 7.6152665219622815
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.6152665219622815
#        x: -0.8542552614230199
#      nit: 23
#     nfev: 23
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: 1.6042736742586439
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.6042736742586439
#        x: -0.8554996960666028
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=7
# Error message: NaN result encountered.
# Current function value: 1.3476620255155958
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.3476620255155958
#        x: -0.8554996960666028
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=8
# Error message: NaN result encountered.
# Current function value: 1.1532621401590093
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.1532621401590093
#        x: -0.8554974370570625
#      nit: 25
#     nfev: 25
# Error at t=14, i_a=0
# Error message: NaN result encountered.
# Current function value: 3.191154379710207
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.191154379710207
#        x: -0.8750277550302624
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=0
# Error message: NaN result encountered.
# Current function value: 2.726195655317011
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.726195655317011
#        x: -0.846095680603663
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=2
# Error message: NaN result encountered.
# Current function value: 1.0249067813860764
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.0249067813860764
#        x: -0.8460963896211654
#      nit: 25
#     nfev: 25
# Error at t=13, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.6390146016380897
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.6390146016380897
#        x: -0.8460979513497816
#      nit: 25
#     nfev: 25
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: 5.156426758657737
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.156426758657737
#        x: -0.7896529184800991
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=5
# Error message: NaN result encountered.
# Current function value: 0.6359473947108369
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.6359473947108369
#        x: -0.7896525725425966
#      nit: 27
#     nfev: 27
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 2.7291847332657104
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.7291847332657104
#        x: -0.8098731663472826
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: 6.583926496250722
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.583926496250722
#        x: -0.8352730448297793
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=1
# Error message: NaN result encountered.
# Current function value: 5.408520808681157
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.408520808681157
#        x: -0.8142227440686677
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=3
# Error message: NaN result encountered.
# Current function value: 3.0867020749115883
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.0867020749115883
#        x: -0.814223660865371
#      nit: 25
#     nfev: 25
# Error at t=7, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=7, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=7, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6219868320748505
#      nit: 25
#     nfev: 25
# Error at t=7, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5835600916294938
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.413026939476369
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.413026939476369
#        x: -0.7363934755065781
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6604135725202072
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=4
# Error message: NaN result encountered.
# Current function value: 3.919847356710002
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.919847356710002
#        x: -0.6390554139896982
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=6
# Error message: NaN result encountered.
# Current function value: 0.006374156650980067
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.006374156650980067
#        x: -0.8642411614661488
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=8
# Error message: NaN result encountered.
# Current function value: -0.39989548090218513
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.39989548090218513
#        x: -0.8642418476987861
#      nit: 26
#     nfev: 26
# Error at t=4, i_a=9
# Error message: NaN result encountered.
# Current function value: -0.5757626268365136
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.5757626268365136
#        x: -0.8642418476987861
#      nit: 26
#     nfev: 26
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=6
# Error message: NaN result encountered.
# Current function value: 2.210692589210434
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.210692589210434
#        x: -0.7692636224130526
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: 7.111475788194712
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.111475788194712
#        x: -0.8070926703879236
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=1
# Error message: NaN result encountered.
# Current function value: 6.018087638249115
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 6.018087638249115
#        x: -0.8070943546757289
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=3
# Error message: NaN result encountered.
# Current function value: 4.36155040914707
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.36155040914707
#        x: -0.8070941070002012
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=15, i_a=0
# Error message: NaN result encountered.
# Current function value: 4.059059632844177
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.059059632844177
#        x: -0.8699445919601623
#      nit: 23
#     nfev: 23
# Error at t=15, i_a=1
# Error message: NaN result encountered.
# Current function value: 2.941847281329528
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.941847281329528
#        x: -0.8699453559724006
#      nit: 25
#     nfev: 25
# Error at t=14, i_a=1
# Error message: NaN result encountered.
# Current function value: 1.027478636927783
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.027478636927783
#        x: -0.8191086743591562
#      nit: 23
#     nfev: 23
# Error at t=14, i_a=4
# Error message: NaN result encountered.
# Current function value: -0.22909383184883336
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.22909383184883336
#        x: -0.8191066826200073
#      nit: 26
#     nfev: 26
# Error at t=13, i_a=0
# Error message: NaN result encountered.
# Current function value: 3.3101512935837927
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.3101512935837927
#        x: -0.8300291125393575
#      nit: 22
#     nfev: 22
# Error at t=12, i_a=1
# Error message: NaN result encountered.
# Current function value: 1.8929659458671149
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.8929659458671149
#        x: -0.8289094612686384
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=11, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.9461197953067524
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.9461197953067524
#        x: -0.7464249978031501
#      nit: 24
#     nfev: 24
# Error at t=10, i_a=1
# Error message: NaN result encountered.
# Current function value: 5.392136390892889
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.392136390892889
#        x: -0.8031296125598848
#      nit: 24
#     nfev: 24
# Error at t=10, i_a=2
# Error message: NaN result encountered.
# Current function value: 3.610295482345341
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.610295482345341
#        x: -0.8031290000058101
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=8, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6604135725202072
#      nit: 24
#     nfev: 24
# Error at t=8, i_a=4
# Error message: NaN result encountered.
# Current function value: 2.4603087907995818
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.4603087907995818
#        x: -0.6599398182497349
#      nit: 25
#     nfev: 25
# Error at t=7, i_a=1
# Error message: NaN result encountered.
# Current function value: 4.843523262846363
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.843523262846363
#        x: -0.806756939348284
#      nit: 23
#     nfev: 23
# Error at t=7, i_a=5
# Error message: NaN result encountered.
# Current function value: 0.17876309881512198
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.17876309881512198
#        x: -0.8067580441451521
#      nit: 24
#     nfev: 24
# Error at t=7, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.30504204254875
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.30504204254875
#        x: -0.8067603294297134
#      nit: 26
#     nfev: 26
# Error at t=7, i_a=8
# Error message: NaN result encountered.
# Current function value: -0.5091304899399631
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.5091304899399631
#        x: -0.8067603294297134
#      nit: 26
#     nfev: 26
# Error at t=6, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=6, i_a=2
# Error message: NaN result encountered.
# Current function value: 5.620410574683703
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 5.620410574683703
#        x: -0.7382543541018032
#      nit: 24
#     nfev: 24
# Error at t=6, i_a=3
# Error message: NaN result encountered.
# Current function value: 3.9934098701215657
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.9934098701215657
#        x: -0.7382561276839384
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: 9.439608991847711
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 9.439608991847711
#        x: -0.8415491613374787
#      nit: 23
#     nfev: 23
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: 9.902575510404494
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 9.902575510404494
#        x: -0.8425516302030459
#      nit: 23
#     nfev: 23
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: 7.77274285218038
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 7.77274285218038
#        x: -0.842553813486634
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=3, i_a=4
# Error message: NaN result encountered.
# Current function value: 3.587387326365902
# Optimization result details:  message: NaN result encountered.
# ...
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=44, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=44, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=44, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=44, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=44, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=44, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=44, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=44, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=44, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=44, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=44, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=44, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=17, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=17, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7372670534109205
#      nit: 23
#     nfev: 23
# Error at t=17, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6988403129655638
#      nit: 24
#     nfev: 24
# Error at t=17, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6604135725202072
#      nit: 24
#     nfev: 24
# Error at t=17, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6219868320748505
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=26, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=26, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=0
# Error message: NaN result encountered.
# Current function value: 2.5115923431888447
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.5115923431888447
#        x: -0.8940055015975661
#      nit: 23
#     nfev: 23
# Error at t=13, i_a=1
# Error message: NaN result encountered.
# Current function value: 1.9192187374046579
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.9192187374046579
#        x: -0.894005235688479
#      nit: 24
#     nfev: 24
# Error at t=13, i_a=2
# Error message: NaN result encountered.
# Current function value: 1.4898079574745675
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.4898079574745675
#        x: -0.8940030678285367
#      nit: 24
#     nfev: 24
# Error at t=12, i_a=3
# Error message: NaN result encountered.
# Current function value: 0.18461619761055648
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.18461619761055648
#        x: -0.8385988322092034
#      nit: 25
#     nfev: 25
# Error at t=12, i_a=5
# Error message: NaN result encountered.
# Current function value: -0.4238346651202729
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.4238346651202729
#        x: -0.8385972090974202
#      nit: 25
#     nfev: 25
# Error at t=11, i_a=1
# Error message: NaN result encountered.
# Current function value: 2.271074448185437
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.271074448185437
#        x: -0.8162292231774322
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7756937938562771
#      nit: 23
#     nfev: 23
# Error at t=10, i_a=4
# Error message: NaN result encountered.
# Current function value: 0.5235199220148959
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 0.5235199220148959
#        x: -0.7707414488583789
#      nit: 25
#     nfev: 25
# Error at t=10, i_a=7
# Error message: NaN result encountered.
# Current function value: -0.29299160554915776
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: -0.29299160554915776
#        x: -0.7707417722082741
#      nit: 25
#     nfev: 25
# Error at t=9, i_a=0
# Error message: NaN result encountered.
# Current function value: 4.239414731351805
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 4.239414731351805
#        x: -0.8193703847936185
#      nit: 23
#     nfev: 23
# Error at t=9, i_a=1
# Error message: NaN result encountered.
# Current function value: 3.111527573732703
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.111527573732703
#        x: -0.8193703733267954
#      nit: 24
#     nfev: 24
# Error at t=9, i_a=3
# Error message: NaN result encountered.
# Current function value: 1.6265498394052944
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 1.6265498394052944
#        x: -0.8193683321622847
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: 3.6884356975880452
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 3.6884356975880452
#        x: -0.8160249972836893
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: 2.769568649775393
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: 2.769568649775393
#        x: -0.8160234392111096
#      nit: 25
#     nfev: 25

# %%
# Calculates standard errors
jacobian = manual_jacobian(model, est_par, par)

moments_before = model.data.moments_before
moments_before = moments_before.reshape(35)

moments_after = model.data.moments_after
moments_after = moments_after.reshape(35)

data_moments = np.concatenate((moments_before, moments_after))
data_moments = data_moments.reshape(70, 1)

## Ligesom artiklen

def standard_errors(jac, weight_matrix, N = 70):

    model_moments = model_moments_combined(model, est_par, par)
    G = np.zeros((jac.shape))
    for i in range(N):
        G += 1/N*jac*model_moments[i]
  
    G = G.T
    Lambda = np.var(model_moments)

    # diagonal Variance matirx for data moments
    Lambda = np.var(model_moments)
    Lambda = np.eye(N)*Lambda
   
    # Compute (G'WG)
    gwg_inv = la.pinv(G.T @ weight_matrix @ G)

    # Compute the middle term G'WVWG
    middle_term =  G.T @ weight_matrix @ Lambda @ weight_matrix @ G


    # Compute the variance
    variance = 1/N*gwg_inv @ middle_term @ gwg_inv.T
    print(variance.shape)
    variance = np.diag(variance)

    standard_errors = np.sqrt(variance/N)

    return standard_errors

standard_errs = standard_errors(jacobian, model.data.weight_mat, N = 70)
print(standard_errs)

print("Optimization Results:")
print("---------------------")
print(f'{"Parameter":<15} {"Estimate":<15} {"Std. Error":<15}')
for param, estimate, error in zip(est_par, par, standard_errs):
    print(f'{param:<15} {estimate:>15.3f} {error:>15.3f}')
print(f'Objective:               {est_best:.4f}')
print(f'Number of iterations:    {nit}')
# Out:
# (4, 4)
# [1.60838512e-06 2.48031297e-02 1.37908964e-01 2.89401083e+01]
# Optimization Results:
# ---------------------
# Parameter       Estimate        Std. Error
# delta                     0.919           0.000
# gamma                     0.752           0.025
# lambdaa                   3.960           0.138
# cost1                   358.273          28.940
# Objective:               0.0545
# Number of iterations:    6

# %%
# Plot policy functions
value_function_employment_ConSav(model.par, model.sol)
solve_search_and_consumption_ConSav(model.par, model.sol)
search_effort_reference = model.sol.s
time = np.linspace(0, model.par.T, model.par.T)
plt.plot((time+1)*15, search_effort_reference[0,:,0], label = 'low cost', color='teal') 
# plt.plot((time+1)*15, search_effort[1,:,0], label = 'medium cost', color='orange') 
#plt.plot(time, search_effort[2,:], label = 'high' ) 
#plt.text(0.5, 0.96, '(Note that high cost is 0)', horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes)
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
# plt.title('Policy functions with reference dependence, Before the reform')
plt.ylim(0.0, 0.08)
plt.legend()
plt.show()

# %%
# Policy function before reform
model.solve()
search_reference_beforeReform = model.sim.s_total
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, search_reference_beforeReform[:], color='navy', label='Before Reform') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.ylim(0.0, 0.08)
plt.legend()
plt.show()

# %%
# Policy function after reform
model_afterReform = deepcopy(model)
model_afterReform.par.b1 = 342.0/675.0      # Value after reform
model_afterReform.par.b2 = 171.0/675.0      # Value after reform

model_afterReform.allocate()
search_reference_afterReform = model_afterReform.solve()

# true_data_afterReform = model.data.moments_after
# true_data_beforeReform = model.data.moments_before
# mse_reference_afterReform = np.mean((true_data_afterReform - search_reference_afterReform)**2)
# mse_reference_beforeReform = np.mean((true_data_beforeReform - search_reference_beforeReform)**2)

# Now plotting search_reference_afterReform
time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, search_reference_afterReform, label='After Reform', color='maroon')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
#Replicating figure 7(b) from the paper
after = model_standard.data.moments_after
before = model_standard.data.moments_before

time = np.linspace(0, model.par.T_sim, model.par.T_sim)
plt.plot((time+1)*15, search_reference_beforeReform[:model.par.T_sim], color='Blue', label='Estimated hazard, Before', linestyle='--')
plt.plot((time+1)*15, search_reference_afterReform, label='Estimated hazard, After', color='Red', linestyle='--')
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='Blue')
plt.plot((time+1)*15, after, label='Actual hazard, After', color='Red')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
# plt.title('Real and estimated hazard rates of the reference denpendence model')
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %% [markdown]
# # Model with **NO** reference dependence (standard model)

# %%
# Setup
model_standard.par.eta = 0.0     # Removes reference dependence
model_standard.par.types = 3     # Allow for heterogeneity
model_standard.allocate()

# Estimation setup
est_par = ['delta','gamma', 'cost1', 'cost2', 'cost3', 'type_shares1', 'type_shares3'] # Parameters to estimate
theta0 = [0.9, 0.9, 84, 242, 310, 0.4, 0, -0.3] # Initial guesses
bounds = [(0.5,1.0), (0.001, 50.0), (0.0, 100), (30, 300), (300, 1000), (0,0.9), (0,1-model_standard.par.type_shares1)] # Bounds for the parameters


# Random starting values:
model.par.noOfParams = len(est_par)
model.par.noSearchInits = 10
np.random.seed(180615)
est_best = np.inf

for i in range(model.par.noSearchInits):

    theta0 = [np.random.uniform(model.par.lb_delta, model.par.ub_delta),
              np.random.uniform(model.par.lb_gamma,model.par.ub_gamma),
              np.random.uniform(model.par.lb_lsc,model.par.ub_lsc),
              np.random.uniform(model.par.lb_msc,model.par.ub_msc),
              np.random.uniform(model.par.lb_hsc,model.par.ub_hsc),
              np.random.uniform(model.par.lb_share,model.par.ub_share),
              np.random.uniform(model.par.lb_share,model.par.ub_share)]

    

    try:
        # Perform the method of simulated moments
        est = method_simulated_moments(model_standard, est_par, theta0, bounds, weight=True)

        # Check if the current estimate is better than the best estimate
        if est.fun < est_best:
            est_best = est.fun
            par = est.x
            nit = est.nit
            obj_standard = est_best

    except Exception as e:
        # Print the exception message and continue with the next iteration
        print(f"Iteration {i} failed with error: {e}")
        continue

# print("Optimization Results:")
# print("---------------------")
# print(f'{"Parameter":<15} {"Estimate":<15}')
# for param, estimate in zip(est_par, par):
#     print(f'{param:<15} {estimate:>15.3f}')
# print(f'Objective:               {est_best:.4f}')
# print(f'Number of iterations:    {nit}')
# Out:
# Error at t=44, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=44, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=44, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=44, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=44, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=44, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=43, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=43, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=43, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=43, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=43, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=43, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=43, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=43, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=43, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=43, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=42, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=42, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=42, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=42, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=42, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=42, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=42, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=42, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=42, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=42, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=41, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=41, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=41, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=41, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=41, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=40, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=40, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=40, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=40, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=40, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=39, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=39, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=39, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=39, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=39, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=38, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=38, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=38, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=38, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=38, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=37, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=37, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=37, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=37, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=37, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=36, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=36, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=36, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=36, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=36, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=35, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=35, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=35, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=35, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=35, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=34, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=34, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=34, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=34, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=34, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=33, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=33, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=33, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=33, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=33, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=32, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=32, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=32, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=32, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=32, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=31, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=31, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=31, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=31, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=31, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=30, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=30, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=30, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=30, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=30, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=29, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=29, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=29, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=29, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=29, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=28, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=28, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=28, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=28, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=28, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=27, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=27, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=27, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=27, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=27, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=26, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=26, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
#      nit: 23
#     nfev: 23
# Error at t=26, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7355591982800157
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.697132457834659
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6587057173893024
#      nit: 24
#     nfev: 24
# Error at t=26, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6202789769439456
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.581852236498589
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=26, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=25, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8508394196160858
#      nit: 21
#     nfev: 21
# Error at t=25, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.8124126791707291
#      nit: 22
#     nfev: 22
# Error at t=25, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7739859387253724
# ...
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6125936288548743
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5741668884095177
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=6, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=5, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=5, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=4, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=4, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=3, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=3, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=2, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=2, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=1, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=1, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=0
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.7073795886200875
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=1
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6689528481747308
#      nit: 24
#     nfev: 24
# Error at t=0, i_a=2
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.6305261077293741
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=3
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5920993672840175
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=4
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=5
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=6
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=7
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=8
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25
# Error at t=0, i_a=9
# Error message: NaN result encountered.
# Current function value: nan
# Optimization result details:  message: NaN result encountered.
#  success: False
#   status: 2
#      fun: nan
#        x: -0.5562305898749054
#      nit: 25
#     nfev: 25

# %%
# Calculates standard errors
jacobian = manual_jacobian(model_standard, est_par, par)

moments_before = model_standard.data.moments_before
moments_before = moments_before.reshape(35)

moments_after = model_standard.data.moments_after
moments_after = moments_after.reshape(35)

data_moments = np.concatenate((moments_before, moments_after))
data_moments = data_moments.reshape(70, 1)

## Ligesom artiklen

standard_errs = standard_errors(jacobian, model_standard.data.weight_mat, N = 70)
print(standard_errs)

print("Optimization Results:")
print("---------------------")
print(f'{"Parameter":<15} {"Estimate":<15} {"Std. Error":<15}')
for param, estimate, error in zip(est_par, par, standard_errs):
    print(f'{param:<15} {estimate:>15.3f} {error:>15.3f}')
print(f'Objective:               {est_best:.4f}')
print(f'Number of iterations:    {nit}')
# Out:
# (7, 7)
# [7.11599544e-03 3.06387423e-02 5.58675353e-01 7.38945852e-01
#  1.94395550e-17 1.61981352e-02 4.53537431e-02]
# Optimization Results:
# ---------------------
# Parameter       Estimate        Std. Error
# delta                     0.734           0.007
# gamma                     0.898           0.031
# cost1                     5.896           0.559
# cost2                    92.188           0.739
# cost3                   578.459           0.000
# type_shares1              0.177           0.016
# type_shares3              0.000           0.045
# Objective:               0.0941
# Number of iterations:    14

# %%
# Plot policy functions
value_function_employment_ConSav(model_standard.par, model_standard.sol)
solve_search_and_consumption_ConSav(model_standard.par, model_standard.sol)
search_effort_standard = model_standard.sol.s

time = np.linspace(0, model_standard.par.T, model_standard.par.T)
plt.plot((time+1)*15, search_effort_standard[0,:,0], label = 'low cost', color='teal') 
plt.plot((time+1)*15, search_effort_standard[1,:,0], label = 'medium cost', color='orange') 
# plt.plot((time+1)*15, search_effort_standard[2,:], label = 'high', color='brown' ) 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
# plt.title('Policy functions standard model, After the reform')
plt.legend()
plt.show()

# %%
# Policy function before reform
model_standard.par.b1 = 222/675*model_standard.par.w    # High transfers
model_standard.par.b2 = model_standard.par.b1    # Medium transfers
model_standard.allocate()
model_standard.solve()
search_standard_beforeReform = model_standard.sim.s_total

time = np.linspace(0, model_standard.par.T_sim, model_standard.par.T_sim)
plt.plot((time+1)*15, search_standard_beforeReform[:], label='Before Reform', color='navy') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
# Policy function after reform
model_standard.par.b1 = 342.0/675.0      # Value after reform
model_standard.par.b2 = 171.0/675.0      # Value after reform

model_standard.allocate()
model_standard.solve()
search_standard_afterReform = model_standard.sim.s_total

# Now plotting s_forecast
time = np.linspace(0, model_standard.par.T_sim, model_standard.par.T_sim)
plt.plot((time+1)*15, search_standard_afterReform, label='After Reform', color='maroon')
plt.plot((time+1)*15, search_standard_beforeReform[:], label='Before Reform', color='navy') 
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Search Effort')
plt.title('Simulated search Effort with the estimated parameters')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %%
#Replicating figure 7(a) from the paper
after = model_standard.data.moments_after
before = model_standard.data.moments_before

time = np.linspace(0, model_standard.par.T_sim, model_standard.par.T_sim)
plt.plot((time+1)*15, search_standard_beforeReform, color='Blue', label='Estimated hazard, Before', linestyle='--')
plt.plot((time+1)*15, search_standard_afterReform, label='Estimated hazard, After', color='Red', linestyle='--')
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='Blue')
plt.plot((time+1)*15, after, label='Actual hazard, After', color='Red')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
# plt.title('Real and estimated hazard rates of the standard model')
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.legend()
plt.ylim(0.0, 0.08)
plt.show()

# %% [markdown]
# # **Comparison of the standard model and reference dependence**
# ### Through the Mean Square Error

# %%
# true_data_afterReform = model_standard.data.moments_after
# true_data_beforeReform = model_standard.data.moments_before

# # Get the mean square errors
# mse_standard_afterReform = np.mean((true_data_afterReform - search_standard_afterReform)**2)
# mse_standard_beforeReform = np.mean((true_data_beforeReform - search_standard_beforeReform)**2)

# # Comparison after reform
# comparison1 = "smaller" if mse_reference_afterReform < mse_standard_afterReform else "bigger" if mse_reference_afterReform > mse_standard_afterReform else "equal"
# comparison2 = "WITH reference dependence" if mse_reference_afterReform < mse_standard_afterReform else "WITHOUT reference dependence" 

# # Comparison before reform
# comparison3 = "smaller" if mse_reference_beforeReform < mse_standard_beforeReform else "bigger" if mse_reference_beforeReform > mse_standard_beforeReform else "equal"
# comparison4 = "WITH reference dependence" if mse_reference_beforeReform < mse_standard_beforeReform else "WITHOUT reference dependence"


# print("Before the reform: ")
# print("-" * 100)
# print(f"The mean square error from the model \033[1mwith\033[0m reference dependence is {mse_reference_beforeReform}")
# print(f"The mean square error from the model \033[1mwithout\033[0m reference dependence is {mse_standard_beforeReform}")
# print(f"The mean square error for the model \033[1mwith\033[0m reference dependence is \033[1m{comparison3}\033[0m than the model without.")
# print(f"Best model: \033[1m{comparison4}\033[0m.")
# print("-" * 100)



# print("After the reform:")
# print("-" * 100)
# print(f"The mean square error from the model \033[1mwith\033[0m reference dependence is {mse_reference_afterReform}")
# print(f"The mean square error from the model \033[1mwithout\033[0m reference dependence is {mse_standard_afterReform}")
# print(f"The mean square error for the model \033[1mwith\033[0m reference dependence is \033[1m{comparison1}\033[0m than the model without.")
# print(f"Best model: \033[1m{comparison2}\033[0m.")
# print("-" * 100)

# %% [markdown]
# ### Through objective function

# %%
# Comparison
comparison1 = "Reference Dependent Model" if obj_ref < obj_standard else "Standard Model" if obj_ref > obj_standard else "They are equally good"


print("Comparison: ")
print("-" * 100)
print(f"The objective function from the model \033[1mwith\033[0m reference dependence is {obj_ref}")
print(f"The objective function from the model \033[1mwithout\033[0m reference dependence is {obj_standard}")
print(f"Best model: \033[1m{comparison1}\033[0m.")
print("-" * 100)
# Out:
# Comparison:
# ----------------------------------------------------------------------------------------------------
# The objective function from the model with reference dependence is 0.05452851130945735
# The objective function from the model without reference dependence is 0.09414620975565913
# Best model: Reference Dependent Model.
# ----------------------------------------------------------------------------------------------------

# %%
after = model_standard.data.moments_after

time = np.linspace(0, model_standard.par.T_sim, model_standard.par.T_sim)     # x-axis
plt.plot((time+1)*15, search_standard_afterReform, label='Standard model', color='salmon', linestyle='--')                     # Model with no reference dependence
plt.plot((time+1)*15, search_reference_afterReform, label='Reference dependence', color='crimson', linestyle='--')                         # Model with reference dependence
plt.plot((time+1)*15, after, label='Actual hazard, After', color='tan')                        # True data
# Make a vertical line at 90, 270 and 360
plt.axvline(x=90, color='silver')
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.legend()
# plt.title('Real and estimated hazard rates before the reform')
plt.ylim(0.0, 0.08)
plt.show()

# %%
before = model_standard.data.moments_before

time = np.linspace(0, model_standard.par.T_sim, model_standard.par.T_sim)     # x-axis
plt.plot((time+1)*15, search_standard_beforeReform, label='Standard model', color='salmon', linestyle='--')                            # Model with no reference dependence
plt.plot((time+1)*15, search_reference_beforeReform, label='Reference dependence', color='crimson', linestyle='--')                                # Model with reference dependence
plt.plot((time+1)*15, before, label='Actual hazard, Before', color='tan')                           # True data
plt.axvline(x=270, color='silver')
plt.axvline(x=360, color='silver')
plt.xlabel('Days elapsed since UI claimed')
plt.ylabel('Hazard Rate')
plt.legend()
# plt.title('Real and estimated hazard rates before the reform')
plt.ylim(0.0, 0.08)
plt.show()
