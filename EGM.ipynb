# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
from EGM import *
from consumption_saving import *

# %%
from Model import ReferenceDependenceClass
model = ReferenceDependenceClass()

# %%
EGM(model.par, model.sol)

# %%
model.sol.a_next_e[-1,0,:]
# Out:
# array([-0.84678813, -0.83814582, -0.82950351, -0.82086121, -0.8122189 ,
#        -0.80357659, -0.79493428, -0.78629197, -0.77764966, -0.76900736,
#        -0.76036505, -0.75172274, -0.74308043, -0.73443812, -0.72579581,
#        -0.7171535 , -0.7085112 , -0.69986889, -0.69122658, -0.68258427,
#        -0.67394196, -0.66529965, -0.65665734, -0.64801504, -0.63937273,
#        -0.63073042, -0.62208811, -0.6134458 , -0.60480349, -0.59616118,
#        -0.58751888, -0.57887657, -0.57023426, -0.56159195, -0.55294964,
#        -0.54430733, -0.53566502, -0.52702272, -0.51838041, -0.5097381 ,
#        -0.50109579, -0.49245348, -0.48381117, -0.47516887, -0.46652656,
#        -0.45788425, -0.44924194, -0.44059963, -0.43195732, -0.42331501,
#        -0.41467271, -0.4060304 , -0.39738809, -0.38874578, -0.38010347,
#        -0.37146116, -0.36281885, -0.35417655, -0.34553424, -0.33689193,
#        -0.32824962, -0.31960731, -0.31096501, -0.30232271, -0.29368042,
# ...

# %%
model1 = model.copy()
# model1.par.L = -0.00
# model1.par.a_grid = np.linspace(model1.par.L, model1.par.A_0, 20)
model1.par.euler = False

# %%
value_function_employment(model1.par, model1.sol)

# %%
import matplotlib.pyplot as plt
plt.plot(model.sol.a_next_e[5,-5,:], label='Euler')
plt.plot(model1.sol.a_next_e[5,-5,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('a_next')
plt.title('a next employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(model.sol.a_next_e[0,:,50], label='Euler')
plt.plot(model1.sol.a_next_e[0,:,50], label='VFI')
plt.ylabel('a_next')
plt.title('a next employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.a_grid, model.sol.c_e[5,-3,:], label='Euler')
plt.plot(model1.par.a_grid, model1.sol.c_e[5,-3,:], label='VFI')
plt.xlabel('a grid')
plt.ylabel('c')
plt.title('consumption employed')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(model.par.V_e[-1,0,:], label='Euler')
plt.plot(model1.par.V_e[-1,0,:], label='VFI')
plt.legend()

# %%
print(model.par.V_e)
# Out:
# [[[-9.31168769e-01 -9.21518301e-01 -9.11872830e-01 ... -1.82609553e-02
#    -9.12290170e-03  0.00000000e+00]
#   [-9.32034430e-01 -9.22361478e-01 -9.12694221e-01 ... -1.82609504e-02
#    -9.12289986e-03  0.00000000e+00]
#   [-9.33054863e-01 -9.23356420e-01 -9.13663588e-01 ... -1.82609432e-02
#    -9.12289714e-03  0.00000000e+00]
#   ...
#   [-1.19762527e+00 -1.18109776e+00 -1.16474111e+00 ... -1.82760585e-02
#    -9.12622109e-03  0.00000000e+00]
#   [-2.30258509e+00 -2.21557372e+00 -2.13553101e+00 ... -1.83491387e-02
#    -9.13248356e-03  0.00000000e+00]
#   [-4.60517019e+02 -4.43114743e+02 -4.27106202e+02 ... -3.66982773e+00
#    -1.82649671e+00  0.00000000e+00]]
#
#  [[-9.31168769e-01 -9.21518301e-01 -9.11872830e-01 ... -1.82609553e-02
#    -9.12290170e-03  0.00000000e+00]
#   [-9.32034430e-01 -9.22361478e-01 -9.12694221e-01 ... -1.82609504e-02
#    -9.12289986e-03  0.00000000e+00]
#   [-9.33054863e-01 -9.23356420e-01 -9.13663588e-01 ... -1.82609432e-02
# ...
