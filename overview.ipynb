# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = loadmat('Data\Moments_hazard.mat')

# Access the 'Moments' table
moments = data['Moments']

# Access the 'VCcontrols' table
vc_controls = data['VCcontrol']

# Generate x-axis values based on the number of observations
x_values = np.arange(len(moments)) * 15

# Plot the data with adjusted x-axis and limited range
plt.plot(x_values, moments)
plt.xlabel('Days')
plt.ylabel('Moment Values')
plt.title('Moment Values Over Time')
plt.grid(True)
# plt.xlim(0, 500)  # Set the x-axis limits
plt.show()
